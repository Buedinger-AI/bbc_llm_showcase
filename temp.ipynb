# %%
import pandas as pd
raw_articles = pd.read_csv('data/articles.csv')
filtered_articles = pd.read_csv('data/filtered_articles.csv')

filtered_articles
# Out:
#      Unnamed: 0                                           headline  \
# 0             9  Biden says he 'screwed up' debate but vows to ...
# 1            20  'Something needs to happen' - Democratic voter...
# 2            13   Chess star, 9, to become youngest England player
# 3            38     Who could replace Biden as Democratic nominee?
# 4            47                    How the BBC reports polling day
# ..          ...                                                ...
# 453        2012  Raygun apologises to Australian breakdancing c...
# 454        2008    US accuses Russia of 2024 election interference
# 455        2007                Trump Media shares erase 2024 gains
# 456        2020  63 golds on offer on day seven - Paris Paralym...
# 457        2056  Storey extends record as GB win 13 medals on W...
#
#                                                content            timestamp  \
# 0    US President Joe Biden has admitted he "screwe...  2024-07-04 11:39:19
# ...

# %%
filtered_articles.head(20)
# Out:
#     Unnamed: 0                                           headline  \
# 0            9  Biden says he 'screwed up' debate but vows to ...
# 1           20  'Something needs to happen' - Democratic voter...
# 2           13   Chess star, 9, to become youngest England player
# 3           38     Who could replace Biden as Democratic nominee?
# 4           47                    How the BBC reports polling day
# 5           58  Labour set for general election landslide - ex...
# 6           91       Euro 2024: France beat Portugal on penalties
# 7           96     Victoria Starmer: Who is the new UK PM's wife?
# 8           94      Flames, chains and grains: Africa's top shots
# 9          109  French far right seeks vote win but deadlock l...
# 10         121  Murray's Wimbledon career over as Raducanu pul...
# 11         115  'I'm worried' - Democrats at Biden rally open ...
# 12         141  Democrats weigh risks and rewards of losing Biden
# ...
